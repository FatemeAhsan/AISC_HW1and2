# %%
import pandas as pd

# %%
df = pd.read_csv('files/possum.csv').drop('case', axis=1)
df
# Out:
#      site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth
# 0       1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5  \
# 1       1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99      7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# 2        51.9  15.5   30.0   34.0
# 3        52.2  15.2   28.0   34.0
# 4        53.2  15.1   28.5   33.0
# ..        ...   ...    ...    ...
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5
#
# [104 rows x 13 columns]

# %%
df_nona = df.dropna()
df_nona
# Out:
#      site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth
# 0       1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5  \
# 1       1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99      7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# 2        51.9  15.5   30.0   34.0
# 3        52.2  15.2   28.0   34.0
# 4        53.2  15.1   28.5   33.0
# ..        ...   ...    ...    ...
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5
#
# [101 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
for c in df_nona.columns:
    plt.figure(figsize=[3, 2])
    plt.title(c)
    plt.hist(df_nona[c], color=np.random.rand(3))
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

df_encoded = df_nona.copy()

df_encoded['Pop'] = encoder.fit_transform(df_encoded['Pop'])
df_encoded['sex'] = encoder.fit_transform(df_encoded['sex'])

# %%
df_encoded
# Out:
#      site  Pop  sex  age  hdlngth  skullw  totlngth  taill  footlgth
# 0       1    0    1  8.0     94.1    60.4      89.0   36.0      74.5  \
# 1       1    0    0  6.0     92.5    57.6      91.5   36.5      72.5
# 2       1    0    0  6.0     94.0    60.0      95.5   39.0      75.4
# 3       1    0    0  6.0     93.2    57.1      92.0   38.0      76.1
# 4       1    0    0  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...  ...  ...  ...      ...     ...       ...    ...       ...
# 99      7    1    1  1.0     89.5    56.0      81.5   36.5      66.0
# 100     7    1    1  1.0     88.6    54.7      82.5   39.0      64.4
# 101     7    1    0  6.0     92.4    55.0      89.0   38.0      63.5
# 102     7    1    1  4.0     91.5    55.2      82.5   36.5      62.9
# 103     7    1    0  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# 2        51.9  15.5   30.0   34.0
# 3        52.2  15.2   28.0   34.0
# 4        53.2  15.1   28.5   33.0
# ..        ...   ...    ...    ...
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5
#
# [101 rows x 13 columns]

# %%
df_y = df_encoded[['age']]
df_x = df_encoded.drop('age', axis=1)
df_x
# Out:
#      site  Pop  sex  hdlngth  skullw  totlngth  taill  footlgth  earconch
# 0       1    0    1     94.1    60.4      89.0   36.0      74.5      54.5  \
# 1       1    0    0     92.5    57.6      91.5   36.5      72.5      51.2
# 2       1    0    0     94.0    60.0      95.5   39.0      75.4      51.9
# 3       1    0    0     93.2    57.1      92.0   38.0      76.1      52.2
# 4       1    0    0     91.5    56.3      85.5   36.0      71.0      53.2
# ..    ...  ...  ...      ...     ...       ...    ...       ...       ...
# 99      7    1    1     89.5    56.0      81.5   36.5      66.0      46.8
# 100     7    1    1     88.6    54.7      82.5   39.0      64.4      48.0
# 101     7    1    0     92.4    55.0      89.0   38.0      63.5      45.4
# 102     7    1    1     91.5    55.2      82.5   36.5      62.9      45.9
# 103     7    1    0     93.6    59.9      89.0   40.0      67.6      46.0
#
#       eye  chest  belly
# 0    15.2   28.0   36.0
# 1    16.0   28.5   33.0
# 2    15.5   30.0   34.0
# 3    15.2   28.0   34.0
# 4    15.1   28.5   33.0
# ..    ...    ...    ...
# 99   14.8   23.0   27.0
# 100  14.0   25.0   33.0
# 101  13.0   25.0   30.0
# 102  15.4   25.0   29.0
# 103  14.8   28.5   33.5
#
# [101 rows x 12 columns]

# %%
df_y
# Out:
#      age
# 0    8.0
# 1    6.0
# 2    6.0
# 3    6.0
# 4    2.0
# ..   ...
# 99   1.0
# 100  1.0
# 101  6.0
# 102  4.0
# 103  3.0
#
# [101 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df_x_train, df_x_val, df_y_train, df_y_val = train_test_split(df_x, df_y, test_size=0.15)

df_x_train.shape, df_y_train.shape, df_x_val.shape, df_y_val.shape
# Out:
# ((85, 12), (85, 1), (16, 12), (16, 1))

# %%
df_x_train
# Out:
#      site  Pop  sex  hdlngth  skullw  totlngth  taill  footlgth  earconch
# 10      1    0    0     93.3    57.2      89.5   39.0      77.2      51.3  \
# 50      3    1    0     95.6    59.6      85.0   36.0      64.0      43.9
# 102     7    1    1     91.5    55.2      82.5   36.5      62.9      45.9
# 53      4    1    1     96.9    63.0      91.5   43.0      71.3      46.0
# 14      1    0    1     92.9    57.6      85.5   34.0      69.7      51.8
# ..    ...  ...  ...      ...     ...       ...    ...       ...       ...
# 61      5    1    0     91.3    58.0      90.5   39.0      65.5      41.3
# 0       1    0    1     94.1    60.4      89.0   36.0      74.5      54.5
# 16      1    0    0     94.7    67.7      89.5   36.5      73.2      53.2
# 33      2    0    1     90.6    55.7      85.5   36.5      73.1      53.1
# 26      1    0    0     90.5    54.5      85.0   35.0      70.3      50.8
#
#       eye  chest  belly
# 10   14.9   31.0   34.0
# 50   17.4   28.0   38.5
# 102  15.4   25.0   29.0
# 53   17.5   30.0   36.5
# 14   15.7   28.0   35.0
# ..    ...    ...    ...
# 61   16.0   27.0   32.0
# 0    15.2   28.0   36.0
# 16   14.7   29.0   31.0
# 33   14.4   26.0   28.5
# 26   14.2   23.0   28.0
#
# [85 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

x_train_nrm = scaler.fit_transform(df_x_train)
x_val_nrm = scaler.transform(df_x_val)

# %%
x_train_nrm
# Out:
# array([[-1.11048481, -1.13898959, -1.11213403, ..., -0.17208082,
#          1.90401334,  0.46798802],
#        [-0.23649213,  0.87797115, -1.11213403, ...,  2.11336754,
#          0.43717527,  2.038211  ],
#        [ 1.51149321,  0.87797115,  0.8991722 , ...,  0.28500885,
#         -1.0296628 , -1.27670417],
#        ...,
#        [-1.11048481, -1.13898959, -1.11213403, ..., -0.35491669,
#          0.92612129, -0.57882729],
#        [-0.67348847, -1.13898959,  0.8991722 , ..., -0.62917049,
#         -0.54071678, -1.45117339],
#        [-1.11048481, -1.13898959, -1.11213403, ..., -0.81200636,
#         -2.00755485, -1.62564261]])

# %%
x_train_nrm.shape
# Out:
# (85, 12)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model1 = Sequential()

model1.add(Dense(512, activation='relu', input_shape=x_train_nrm.shape[1:]))

model1.add(Dense(256, activation='relu'))

model1.add(Dense(64, activation='relu'))

model1.add(Dense(32, activation='relu'))

model1.add(Dense(1, 'linear'))

model1.compile(optimizer='adam', loss='mse', metrics='mae')

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               6656
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 156,545
# Trainable params: 156,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train = df_y_train.values
y_val = df_y_val.values

# %%
import tensorflow as tf

# %%
results = model1.fit(x_train_nrm, 
                    y_train, 
                    epochs=20,
                    batch_size=32,
                    validation_data=(x_val_nrm, y_val),
                    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)])
# Out:
# Epoch 1/20
# 3/3 [==============================] - 1s 191ms/step - loss: 19.2457 - mae: 3.9291 - val_loss: 9.8113 - val_mae: 2.7909
# Epoch 2/20
# 3/3 [==============================] - 0s 26ms/step - loss: 15.2762 - mae: 3.3618 - val_loss: 6.7496 - val_mae: 2.2110
# Epoch 3/20
# 3/3 [==============================] - 0s 25ms/step - loss: 11.1520 - mae: 2.7468 - val_loss: 3.7723 - val_mae: 1.5603
# Epoch 4/20
# 3/3 [==============================] - 0s 26ms/step - loss: 7.0450 - mae: 2.0883 - val_loss: 2.5519 - val_mae: 1.1624
# Epoch 5/20
# 3/3 [==============================] - 0s 24ms/step - loss: 4.8486 - mae: 1.7596 - val_loss: 3.9351 - val_mae: 1.6782
# Epoch 6/20
# 3/3 [==============================] - 0s 23ms/step - loss: 5.5020 - mae: 1.8919 - val_loss: 4.0152 - val_mae: 1.7134
# Epoch 7/20
# 3/3 [==============================] - 0s 26ms/step - loss: 4.8489 - mae: 1.7347 - val_loss: 2.4821 - val_mae: 1.2412
# Epoch 8/20
# 3/3 [==============================] - 0s 25ms/step - loss: 3.9307 - mae: 1.5373 - val_loss: 2.0169 - val_mae: 1.0710
# Epoch 9/20
# 3/3 [==============================] - 0s 28ms/step - loss: 3.8362 - mae: 1.4999 - val_loss: 1.9567 - val_mae: 1.0551
# Epoch 10/20
# 3/3 [==============================] - 0s 23ms/step - loss: 3.5776 - mae: 1.4402 - val_loss: 2.0748 - val_mae: 1.0833
# Epoch 11/20
# 3/3 [==============================] - 0s 24ms/step - loss: 3.1328 - mae: 1.3645 - val_loss: 2.5565 - val_mae: 1.3075
# Epoch 12/20
# 3/3 [==============================] - 0s 24ms/step - loss: 3.0185 - mae: 1.3750 - val_loss: 3.0943 - val_mae: 1.4976
# Epoch 13/20
# 3/3 [==============================] - 0s 24ms/step - loss: 2.9806 - mae: 1.3782 - val_loss: 2.8751 - val_mae: 1.4345
# Epoch 14/20
# 1/3 [=========>....................] - ETA: 0s - loss: 2.2983 - mae: 1.1245Restoring model weights from the end of the best epoch: 9.
# 3/3 [==============================] - 0s 34ms/step - loss: 2.7504 - mae: 1.3107 - val_loss: 2.5246 - val_mae: 1.3025
# Epoch 14: early stopping

# %%
def plot_losses():
    plt.plot(results.history['loss'], label='loss')
    plt.plot(results.history['val_loss'], label='val_loss')
    plt.legend()

# %%
plot_losses()

# %%
model2 = Sequential()

model2.add(Dense(256, activation='relu', input_shape=x_train_nrm.shape[1:]))

model2.add(Dense(64, activation='relu'))

model2.add(Dense(32, activation='relu'))

model2.add(Dense(1, 'linear'))

model2.compile(optimizer='adam', loss='mse', metrics='mae')

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               3328
#
#  dense_6 (Dense)             (None, 64)                16448
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 21,889
# Trainable params: 21,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model2.fit(x_train_nrm, 
                    y_train, 
                    epochs=20,
                    batch_size=32,
                    validation_data=(x_val_nrm, y_val),
                    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)])
# Out:
# Epoch 1/20
# 3/3 [==============================] - 1s 120ms/step - loss: 19.3859 - mae: 3.9523 - val_loss: 10.7452 - val_mae: 2.9493
# Epoch 2/20
# 3/3 [==============================] - 0s 61ms/step - loss: 16.7524 - mae: 3.5921 - val_loss: 8.9983 - val_mae: 2.6233
# Epoch 3/20
# 3/3 [==============================] - 0s 25ms/step - loss: 14.5802 - mae: 3.2683 - val_loss: 7.3603 - val_mae: 2.3232
# Epoch 4/20
# 3/3 [==============================] - 0s 23ms/step - loss: 12.2735 - mae: 2.9334 - val_loss: 5.7609 - val_mae: 2.0061
# Epoch 5/20
# 3/3 [==============================] - 0s 30ms/step - loss: 9.9431 - mae: 2.5852 - val_loss: 4.3239 - val_mae: 1.6663
# Epoch 6/20
# 3/3 [==============================] - 0s 39ms/step - loss: 7.8142 - mae: 2.2295 - val_loss: 3.2212 - val_mae: 1.3836
# Epoch 7/20
# 3/3 [==============================] - 0s 35ms/step - loss: 6.0361 - mae: 1.9317 - val_loss: 2.6962 - val_mae: 1.2242
# Epoch 8/20
# 3/3 [==============================] - 0s 29ms/step - loss: 4.9001 - mae: 1.7409 - val_loss: 2.8747 - val_mae: 1.3019
# Epoch 9/20
# 3/3 [==============================] - 0s 39ms/step - loss: 4.3945 - mae: 1.6540 - val_loss: 3.3753 - val_mae: 1.4940
# Epoch 10/20
# 3/3 [==============================] - 0s 37ms/step - loss: 4.5682 - mae: 1.6814 - val_loss: 3.7143 - val_mae: 1.6082
# Epoch 11/20
# 3/3 [==============================] - 0s 29ms/step - loss: 4.5234 - mae: 1.6681 - val_loss: 3.5271 - val_mae: 1.5682
# Epoch 12/20
# 1/3 [=========>....................] - ETA: 0s - loss: 2.9411 - mae: 1.4512Restoring model weights from the end of the best epoch: 7.
# 3/3 [==============================] - 0s 29ms/step - loss: 4.1324 - mae: 1.5846 - val_loss: 3.0245 - val_mae: 1.4377
# Epoch 12: early stopping

# %%
plot_losses()

# %%
model3 = Sequential()

model3.add(Dense(128, activation='relu', input_shape=x_train_nrm.shape[1:]))

model3.add(Dense(64, activation='relu'))

model3.add(Dense(32, activation='relu'))

model3.add(Dense(1, 'linear'))

model3.compile(optimizer='adam', loss='mse', metrics='mae')

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               1664
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 32)                2080
#
#  dense_12 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 12,033
# Trainable params: 12,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model3.fit(x_train_nrm, 
                    y_train, 
                    epochs=20,
                    batch_size=32,
                    validation_data=(x_val_nrm, y_val),
                    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)])
# Out:
# Epoch 1/20
# 3/3 [==============================] - 1s 147ms/step - loss: 21.6419 - mae: 4.2058 - val_loss: 12.4123 - val_mae: 3.1969
# Epoch 2/20
# 3/3 [==============================] - 0s 23ms/step - loss: 18.9873 - mae: 3.8671 - val_loss: 10.7264 - val_mae: 2.9231
# Epoch 3/20
# 3/3 [==============================] - 0s 23ms/step - loss: 16.8144 - mae: 3.5848 - val_loss: 9.3388 - val_mae: 2.6651
# Epoch 4/20
# 3/3 [==============================] - 0s 23ms/step - loss: 15.0122 - mae: 3.3289 - val_loss: 8.0872 - val_mae: 2.4228
# Epoch 5/20
# 3/3 [==============================] - 0s 24ms/step - loss: 13.2428 - mae: 3.0795 - val_loss: 6.8723 - val_mae: 2.2138
# Epoch 6/20
# 3/3 [==============================] - 0s 23ms/step - loss: 11.6192 - mae: 2.8284 - val_loss: 5.6435 - val_mae: 1.9726
# Epoch 7/20
# 3/3 [==============================] - 0s 26ms/step - loss: 9.9527 - mae: 2.5771 - val_loss: 4.4542 - val_mae: 1.7282
# Epoch 8/20
# 3/3 [==============================] - 0s 23ms/step - loss: 8.1929 - mae: 2.3177 - val_loss: 3.4689 - val_mae: 1.5158
# Epoch 9/20
# 3/3 [==============================] - 0s 23ms/step - loss: 6.6830 - mae: 2.0771 - val_loss: 2.8392 - val_mae: 1.3499
# Epoch 10/20
# 3/3 [==============================] - 0s 23ms/step - loss: 5.5268 - mae: 1.8936 - val_loss: 2.6832 - val_mae: 1.2640
# Epoch 11/20
# 3/3 [==============================] - 0s 23ms/step - loss: 4.9422 - mae: 1.7689 - val_loss: 2.9907 - val_mae: 1.3490
# Epoch 12/20
# 3/3 [==============================] - 0s 22ms/step - loss: 4.8408 - mae: 1.7461 - val_loss: 3.3974 - val_mae: 1.4690
# Epoch 13/20
# 3/3 [==============================] - 0s 22ms/step - loss: 4.7361 - mae: 1.7275 - val_loss: 3.5108 - val_mae: 1.5164
# Epoch 14/20
# 3/3 [==============================] - 0s 22ms/step - loss: 4.4895 - mae: 1.6796 - val_loss: 3.3064 - val_mae: 1.4795
# Epoch 15/20
# 1/3 [=========>....................] - ETA: 0s - loss: 3.5729 - mae: 1.5946Restoring model weights from the end of the best epoch: 10.
# 3/3 [==============================] - 0s 28ms/step - loss: 4.1372 - mae: 1.6137 - val_loss: 2.9622 - val_mae: 1.3975
# Epoch 15: early stopping

# %%
plot_losses()
