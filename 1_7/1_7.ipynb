# %%
import pandas as pd

# %%
df = pd.read_csv('files/garments_worker_productivity.csv')
df
# Out:
#            date   quarter  department        day  team  targeted_productivity
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80  \
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
# ...

# %%
df.describe()
# Out:
#               team  targeted_productivity          smv           wip
# count  1197.000000            1197.000000  1197.000000    691.000000  \
# mean      6.426901               0.729632    15.062172   1190.465991
# std       3.463963               0.097891    10.943219   1837.455001
# min       1.000000               0.070000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    774.500000
# 50%       6.000000               0.750000    15.260000   1039.000000
# 75%       9.000000               0.800000    24.260000   1252.500000
# max      12.000000               0.800000    54.560000  23122.000000
#
#           over_time    incentive    idle_time     idle_men
# count   1197.000000  1197.000000  1197.000000  1197.000000  \
# mean    4567.460317    38.210526     0.730159     0.369256
# std     3348.823563   160.182643    12.709757     3.268987
# min        0.000000     0.000000     0.000000     0.000000
# ...

# %%
df['department'].unique()
# Out:
# array(['sweing', 'finishing ', 'finishing'], dtype=object)

# %%
df = df.replace('finishing ', 'finishing')
df['department'].unique()
# Out:
# array(['sweing', 'finishing'], dtype=object)

# %%
df = df.drop('day', axis=1)

# %%
df_nona = df.copy()
df_nona['wip'].fillna(df_nona['wip'].mean(), inplace = True)
df_nona
# Out:
#            date   quarter department  team  targeted_productivity    smv
# 0      1/1/2015  Quarter1     sweing     8                   0.80  26.16  \
# 1      1/1/2015  Quarter1  finishing     1                   0.75   3.94
# 2      1/1/2015  Quarter1     sweing    11                   0.80  11.41
# 3      1/1/2015  Quarter1     sweing    12                   0.80  11.41
# 4      1/1/2015  Quarter1     sweing     6                   0.80  25.90
# ...         ...       ...        ...   ...                    ...    ...
# 1192  3/11/2015  Quarter2  finishing    10                   0.75   2.90
# 1193  3/11/2015  Quarter2  finishing     8                   0.70   3.90
# 1194  3/11/2015  Quarter2  finishing     7                   0.65   3.90
# 1195  3/11/2015  Quarter2  finishing     9                   0.75   2.90
# 1196  3/11/2015  Quarter2  finishing     6                   0.70   2.90
#
#               wip  over_time  incentive  idle_time  idle_men
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
for c in df.columns[1:]:
    plt.figure(figsize=[5, 2])
    plt.title(c)
    plt.hist(df_nona[c], color=np.random.rand(3))
    plt.show()

# %%
df_nona_no_date = df_nona.drop('date', axis=1)
df_nona_no_date
# Out:
#        quarter department  team  targeted_productivity    smv          wip
# 0     Quarter1     sweing     8                   0.80  26.16  1108.000000  \
# 1     Quarter1  finishing     1                   0.75   3.94  1190.465991
# 2     Quarter1     sweing    11                   0.80  11.41   968.000000
# 3     Quarter1     sweing    12                   0.80  11.41   968.000000
# 4     Quarter1     sweing     6                   0.80  25.90  1170.000000
# ...        ...        ...   ...                    ...    ...          ...
# 1192  Quarter2  finishing    10                   0.75   2.90  1190.465991
# 1193  Quarter2  finishing     8                   0.70   3.90  1190.465991
# 1194  Quarter2  finishing     7                   0.65   3.90  1190.465991
# 1195  Quarter2  finishing     9                   0.75   2.90  1190.465991
# 1196  Quarter2  finishing     6                   0.70   2.90  1190.465991
#
#       over_time  incentive  idle_time  idle_men  no_of_style_change
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

df_encoded = df_nona_no_date.copy()

df_encoded['quarter'] = encoder.fit_transform(df_encoded['quarter'])
df_encoded['department'] = encoder.fit_transform(df_encoded['department'])

# %%
df_encoded
# Out:
#       quarter  department  team  targeted_productivity    smv          wip
# 0           0           1     8                   0.80  26.16  1108.000000  \
# 1           0           0     1                   0.75   3.94  1190.465991
# 2           0           1    11                   0.80  11.41   968.000000
# 3           0           1    12                   0.80  11.41   968.000000
# 4           0           1     6                   0.80  25.90  1170.000000
# ...       ...         ...   ...                    ...    ...          ...
# 1192        1           0    10                   0.75   2.90  1190.465991
# 1193        1           0     8                   0.70   3.90  1190.465991
# 1194        1           0     7                   0.65   3.90  1190.465991
# 1195        1           0     9                   0.75   2.90  1190.465991
# 1196        1           0     6                   0.70   2.90  1190.465991
#
#       over_time  incentive  idle_time  idle_men  no_of_style_change
# ...

# %%
for c in df_encoded.columns[:-1]:
  plt.figure(figsize=[4, 3])
  plt.scatter(df_encoded[[c]], df_encoded[df_encoded.columns[-1]], color=np.random.rand(3))
  plt.xlabel(c)
  plt.ylabel(df.columns[-1])
  plt.title(f'{df.columns[-1]} with {c}')
  plt.show()

# %%
df_encoded_one_hot = df_encoded.drop('quarter', axis=1)
df_encoded_one_hot = df_encoded_one_hot.join(pd.get_dummies(df_encoded['quarter'], prefix='q'))
df_encoded_one_hot
# Out:
#       department  team  targeted_productivity    smv          wip  over_time
# 0              1     8                   0.80  26.16  1108.000000       7080  \
# 1              0     1                   0.75   3.94  1190.465991        960
# 2              1    11                   0.80  11.41   968.000000       3660
# 3              1    12                   0.80  11.41   968.000000       3660
# 4              1     6                   0.80  25.90  1170.000000       1920
# ...          ...   ...                    ...    ...          ...        ...
# 1192           0    10                   0.75   2.90  1190.465991        960
# 1193           0     8                   0.70   3.90  1190.465991        960
# 1194           0     7                   0.65   3.90  1190.465991        960
# 1195           0     9                   0.75   2.90  1190.465991       1800
# 1196           0     6                   0.70   2.90  1190.465991        720
#
# ...

# %%
df_y = df_encoded_one_hot[['actual_productivity']]
df_x = df_encoded_one_hot.drop('actual_productivity', axis=1)
df_x
# Out:
#       department  team  targeted_productivity    smv          wip  over_time
# 0              1     8                   0.80  26.16  1108.000000       7080  \
# 1              0     1                   0.75   3.94  1190.465991        960
# 2              1    11                   0.80  11.41   968.000000       3660
# 3              1    12                   0.80  11.41   968.000000       3660
# 4              1     6                   0.80  25.90  1170.000000       1920
# ...          ...   ...                    ...    ...          ...        ...
# 1192           0    10                   0.75   2.90  1190.465991        960
# 1193           0     8                   0.70   3.90  1190.465991        960
# 1194           0     7                   0.65   3.90  1190.465991        960
# 1195           0     9                   0.75   2.90  1190.465991       1800
# 1196           0     6                   0.70   2.90  1190.465991        720
#
# ...

# %%
df_y
# Out:
#       actual_productivity
# 0                0.940725
# 1                0.886500
# 2                0.800570
# 3                0.800570
# 4                0.800382
# ...                   ...
# 1192             0.628333
# 1193             0.625625
# 1194             0.625625
# 1195             0.505889
# 1196             0.394722
#
# [1197 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df_x_train, df_x_val, df_y_train, df_y_val = train_test_split(df_x, df_y, test_size=0.3, random_state=42)

df_x_val, df_x_test, df_y_val, df_y_test = train_test_split(df_x_val, df_y_val, test_size=0.45, random_state=42)

df_x_train.shape, df_y_train.shape, df_x_val.shape, df_y_val.shape, df_x_test.shape, df_y_test.shape,
# Out:
# ((837, 16), (837, 1), (198, 16), (198, 1), (162, 16), (162, 1))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

x_train_nrm = scaler.fit_transform(df_x_train)
x_val_nrm = scaler.transform(df_x_val)
x_test_nrm = scaler.transform(df_x_test)

# %%
x_train_nrm
# Out:
# array([[-1.1289183 ,  1.35109836,  0.70817577, ..., -0.44432521,
#         -0.50484905, -0.19937791],
#        [ 0.8858037 ,  1.06385697,  0.20653129, ..., -0.44432521,
#         -0.50484905, -0.19937791],
#        [-1.1289183 , -0.08510856, -1.29840216, ..., -0.44432521,
#         -0.50484905, -0.19937791],
#        ...,
#        [-1.1289183 , -0.37234994, -1.29840216, ..., -0.44432521,
#         -0.50484905, -0.19937791],
#        [ 0.8858037 ,  0.20213283,  0.20653129, ...,  2.25060378,
#         -0.50484905, -0.19937791],
#        [-1.1289183 ,  1.06385697, -0.29511319, ..., -0.44432521,
#         -0.50484905, -0.19937791]])

# %%
x_train_nrm.shape
# Out:
# (837, 16)

# %%
y_train = df_y_train.values
y_val = df_y_val.values
y_test = df_y_test.values

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model1 = Sequential()

model1.add(Dense(256, activation='relu', input_shape=x_train_nrm.shape[1:]))

model1.add(Dense(64, activation='relu'))

model1.add(Dense(32, activation='relu'))

model1.add(Dense(1, 'linear'))

model1.compile(optimizer='adam', loss='mse', metrics='mae')

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 256)               4352
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# ...
# Total params: 22,913
# Trainable params: 22,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# %%
results = model1.fit(x_train_nrm, 
                    y_train, 
                    epochs=20,
                    batch_size=32,
                    validation_data=(x_val_nrm, y_val),
                    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)])
# Out:
# Epoch 1/20
# 27/27 [==============================] - 1s 15ms/step - loss: 0.1946 - mae: 0.3208 - val_loss: 0.0768 - val_mae: 0.1987
# Epoch 2/20
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0306 - mae: 0.1342 - val_loss: 0.1199 - val_mae: 0.1651
# Epoch 3/20
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0255 - mae: 0.1132 - val_loss: 0.0623 - val_mae: 0.1316
# Epoch 4/20
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0221 - mae: 0.1054 - val_loss: 0.1867 - val_mae: 0.1544
# Epoch 5/20
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0241 - mae: 0.1052 - val_loss: 0.0478 - val_mae: 0.1244
# Epoch 6/20
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0175 - mae: 0.0971 - val_loss: 0.0246 - val_mae: 0.1064
# Epoch 7/20
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0163 - mae: 0.0919 - val_loss: 0.0241 - val_mae: 0.1112
# Epoch 8/20
# ...

# %%
model1.evaluate(x_test_nrm, y_test)
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0230 - mae: 0.1098
# [0.023020492866635323, 0.10982213169336319]

# %%
from sklearn.metrics import r2_score

# %%
y_test_hat = model1.predict(x_test_nrm)
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
r2_score(y_test, y_test_hat)
# Out:
# 0.19243883003790585

# %%
def plot_losses():
    plt.plot(results.history['loss'], label='loss')
    plt.plot(results.history['val_loss'], label='val_loss')
    plt.legend()

# %%
plot_losses()
